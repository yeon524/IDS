# %% [markdown]
# <a href="https://colab.research.google.com/github/yeon524/IDS/blob/main/information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 시나리오-data-collection-session.md
# 인적정보-subjects.md
# operation, action 정보-annotion-activity-class.md
# 아이템 정보-data-item.csv
# operation,action과 효율성의 관계-data-openpack-v1.0.0-annotation(outlier포함)
