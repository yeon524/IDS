# %% [markdown]
# <a href="https://colab.research.google.com/github/yeon524/IDS/blob/main/CPLEX%2BOR_TOOLS_%EC%9D%B4%EA%B2%8C%20%EC%B0%90%EC%9E%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# Colab 버전 최종 코드 (튜닝 버전)
# - MILP: PuLP + CPLEX_PY (⚠ cplex 패키지 필수)
# - VRP: OR-Tools CVRP (트럭 용량 160 반영)
# - 케이스 A/B/C/D 4개 한 번에 실행
#   * B: λ 자동 탐색
#   * C: min_cust 자동 탐색
#   * D: (λ, min_cust) 그리드 서치
# =========================================================

# !pip install pulp ortools cplex --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pulp
from ortools.constraint_solver import pywrapcp, routing_enums_pb2

# ---------------------------------------------
# 0) 데이터 로드
# ---------------------------------------------
customer = pd.read_csv("/content/Customer.csv").reset_index().rename(columns={"index": "Customer_ID"})
dc       = pd.read_csv("/content/DistributionCenter.csv").reset_index().rename(columns={"index": "DC_ID"})
truck    = pd.read_csv("/content/Truck.csv")

C = len(customer)   # 고객 수
D = len(dc)         # DC 수

TRUCK_CAPACITY = int(truck["CAPACITY"].iloc[0])   # 예: 160
open_cost_j    = dc["COST"].values               # DC 개설비용
dc_capacity_j  = dc["CAPACITY"].values           # DC 보관용량

demand        = customer["DEMAND"].values
total_demand  = demand.sum()

cust_coords = [(customer.loc[i, "X"], customer.loc[i, "Y"]) for i in range(C)]
dc_coords   = [(dc.loc[j, "X"],       dc.loc[j, "Y"])       for j in range(D)]

# ---------------------------------------------
# 1) 유틸 (거리)
# ---------------------------------------------
def euclid(p1, p2):
    return np.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

# ---------------------------------------------
# 2) OR-Tools VRP (트럭 용량 160 반영)
# ---------------------------------------------
def solve_vrp_ortools(demands, dist_matrix, vehicle_capacity, num_vehicles=None, time_limit_sec=10):
    """
    demands: [노드별 수요] (0번은 depot이므로 0)
    dist_matrix: NxN 거리행렬
    vehicle_capacity: 트럭 적재 용량 (여기서는 160)
    num_vehicles: None이면 충분히 많은 차량 허용 (3PL)
    """
    n_nodes = len(demands)
    if num_vehicles is None:
        num_vehicles = n_nodes - 1

    manager = pywrapcp.RoutingIndexManager(n_nodes, num_vehicles, 0)  # depot=0
    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        f = manager.IndexToNode(from_index)
        t = manager.IndexToNode(to_index)
        return int(dist_matrix[f][t] * 1000)  # 정수화

    transit_cb_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_cb_index)

    def demand_callback(from_index):
        node = manager.IndexToNode(from_index)
        return int(demands[node])

    demand_cb_index = routing.RegisterUnaryTransitCallback(demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_cb_index,
        0,
        [vehicle_capacity] * num_vehicles,
        True,
        "Capacity"
    )

    search_params = pywrapcp.DefaultRoutingSearchParameters()
    search_params.first_solution_strategy = routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    search_params.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    search_params.time_limit.FromSeconds(time_limit_sec)

    solution = routing.SolveWithParameters(search_params)
    if not solution:
        return None, None

    routes = []
    total_cost = 0

    for v in range(num_vehicles):
        index = routing.Start(v)
        route = []
        while not routing.IsEnd(index):
            node = manager.IndexToNode(index)
            route.append(node)
            prev_index = index
            index = solution.Value(routing.NextVar(index))
            total_cost += routing.GetArcCostForVehicle(prev_index, index, v)
        node = manager.IndexToNode(index)
        route.append(node)
        if len(route) > 2:
            routes.append(route)

    total_cost = total_cost / 1000.0
    return total_cost, routes

# ---------------------------------------------
# 3) MILP 모델 생성 (제약 on/off 옵션)
# ---------------------------------------------
def build_milp_model(lam=None, min_cust=None, use_capacity=True):
    """
    lam      : 균형 제약 λ (None이면 미적용)
    min_cust : 최소 고객 수 (None이면 미적용)
    use_capacity : True면 DC CAPACITY 제약 적용
    """
    model = pulp.LpProblem("FacilityLocation_Generic", pulp.LpMinimize)

    # 변수
    y = pulp.LpVariable.dicts("OpenDC", range(D), cat="Binary")
    x = pulp.LpVariable.dicts("Assign", (range(C), range(D)), cat="Binary")

    # 거리 비용
    dist_cost = np.zeros((C, D))
    for i in range(C):
        for j in range(D):
            dist_cost[i, j] = euclid(cust_coords[i], dc_coords[j])

    # 목적함수: 개설비 + 배정 거리
    model += (
        pulp.lpSum([y[j] * open_cost_j[j] for j in range(D)]) +
        pulp.lpSum([x[i][j] * dist_cost[i, j] for i in range(C) for j in range(D)])
    )

    # (공통) 각 고객은 정확히 하나의 DC에 배정
    for i in range(C):
        model += pulp.lpSum([x[i][j] for j in range(D)]) == 1

    # (공통) DC가 열려야 배정 가능
    for i in range(C):
        for j in range(D):
            model += x[i][j] <= y[j]

    # (선택) 제약 1: 균형 제약 (λ)  → 각 DC가 담당하는 총 수요 상한
    if lam is not None:
        max_load = lam * total_demand
        for j in range(D):
            model += pulp.lpSum([x[i][j] * demand[i] for i in range(C)]) <= max_load

    # (선택) 제약 2: 최소 고객 수 제약
    if min_cust is not None:
        for j in range(D):
            model += pulp.lpSum([x[i][j] for i in range(C)]) >= min_cust * y[j]

    # (선택) DC CAPACITY 제약
    if use_capacity:
        for j in range(D):
            model += pulp.lpSum([x[i][j] * demand[i] for i in range(C)]) <= dc_capacity_j[j]

    return model, x, y

# ---------------------------------------------
# 4) MILP + VRP 한 번에 푸는 함수 (CPLEX_PY 사용)
# ---------------------------------------------
def solve_milp_and_vrp(case_name, lam=None, min_cust=None,
                       use_capacity=True, vrp_time_limit=10,
                       cplex_msg=False, do_plot=False):
    print("\n============================")
    print(f"[{case_name}] MILP + VRP 풀이 시작")
    print(f"  λ = {lam}, MIN_CUST = {min_cust}, CAPACITY_CONSTR = {use_capacity}")
    print("============================")

    # 1) MILP 모델 생성
    model, x, y = build_milp_model(lam=lam, min_cust=min_cust, use_capacity=use_capacity)

    # 2) CPLEX_PY로 풀기
    try:
        solver = pulp.CPLEX_PY(msg=cplex_msg)
    except Exception as e:
        raise RuntimeError("CPLEX_PY solver를 사용할 수 없습니다. Colab에서 'pip install cplex'가 성공했는지 확인하세요.") from e

    status = model.solve(solver)
    status_str = pulp.LpStatus[status]
    print("MILP Status:", status_str)
    if status_str != "Optimal":
        print(" → 최적해를 찾지 못했거나 infeasible 입니다.")
        return None

    # 3) MILP 결과 해석
    opened_centers = []
    assignment     = {}

    for j in range(D):
        if y[j].value() > 0.5:
            opened_centers.append(j)

    for i in range(C):
        for j in range(D):
            if x[i][j].value() > 0.5:
                assignment[i] = j
                break

    if len(opened_centers) == 0:
        print(" → 어떤 DC도 열리지 않음 (infeasible 취급)")
        return None

    print("개설된 DC:", opened_centers)

    open_cost_total = sum(open_cost_j[j] for j in opened_centers)

    # 4) DC별 VRP (truck capacity 160 반영)
    total_vrp_cost = 0.0
    routes_detail  = {}

    for dc_id in opened_centers:
        cust_list = [i for i in range(C) if assignment[i] == dc_id]
        if not cust_list:
            continue

        # 0: depot, 1~k: 고객
        locs = []
        dc_row = dc.loc[dc_id]
        locs.append((dc_row["X"], dc_row["Y"]))
        for cid in cust_list:
            crow = customer.loc[cid]
            locs.append((crow["X"], crow["Y"]))

        n = len(locs)
        dist_matrix = [[euclid(locs[i], locs[j]) for j in range(n)] for i in range(n)]
        demands = [0] + [int(demand[cid]) for cid in cust_list]

        vrp_dist, routes = solve_vrp_ortools(
            demands=demands,
            dist_matrix=dist_matrix,
            vehicle_capacity=TRUCK_CAPACITY,
            num_vehicles=None,
            time_limit_sec=vrp_time_limit
        )

        if vrp_dist is None:
            print(f"  DC {dc_id} VRP 풀이 실패 (infeasible)")
            return None

        total_vrp_cost += vrp_dist
        routes_detail[dc_id] = {
            "routes": routes,
            "locs":  locs,
            "customers": cust_list
        }

        print(f"  DC {dc_id} | VRP 거리 = {vrp_dist:.2f}, routes = {routes}")

    total_cost = open_cost_total + total_vrp_cost

    print(f"\n[{case_name}] 결과 요약")
    print("  개설된 DC:", opened_centers)
    print("  개설비용:", open_cost_total)
    print("  VRP 비용:", total_vrp_cost)
    print("  총비용:", total_cost)

    # 5) 시각화 (옵션)
    if do_plot:
        for dc_id in opened_centers:
            detail = routes_detail[dc_id]
            routes = detail["routes"]
            locs   = detail["locs"]

            plt.figure(figsize=(6,6))
            x_dc, y_dc = locs[0]
            plt.scatter(x_dc, y_dc, c="red", marker="X", s=180, label=f"DC {dc_id}")

            for route in routes:
                xs, ys = [], []
                for node in route:
                    x, y = locs[node]
                    xs.append(x); ys.append(y)
                    if node != 0:
                        plt.scatter(x, y, c="blue", s=30)
                plt.plot(xs, ys, c="gray", alpha=0.8)

            plt.title(f"{case_name} - DC {dc_id} Routes")
            plt.xlabel("X"); plt.ylabel("Y")
            plt.grid(True); plt.legend()
            plt.show()

    result = {
        "case": case_name,
        "lambda": lam,
        "min_cust": min_cust,
        "opened": opened_centers,
        "open_cost": open_cost_total,
        "vrp_cost": total_vrp_cost,
        "total_cost": total_cost,
        "routes_detail": routes_detail,
        "assignment": assignment
    }
    return result

# ---------------------------------------------
# 5) λ / min_cust 후보 자동 생성
# ---------------------------------------------
def lambda_candidates():
    # 0.10 ~ 0.90, 0.05 간격 (필요하면 간격 더 촘촘하게 조절 가능)
    return [round(0.10 + 0.05 * k, 2) for k in range(0, 17)]

def min_cust_candidates():
    return list(range(5, C + 1, 5))

# ---------------------------------------------
# 6) 4가지 케이스 한 번에 실행 (튜닝 포함)
# ---------------------------------------------
results_all = {}

# A. 제약 없음 (한 번만, 플롯도 켜 둠)
results_all["A_None"] = solve_milp_and_vrp(
    case_name="A_NoConstraint",
    lam=None,
    min_cust=None,
    use_capacity=True,
    vrp_time_limit=10,
    do_plot=True
)

# B. 제약 1만 (λ)  → 여러 λ 중 최적 λ 찾기
print("\n=== B_LambdaOnly — λ grid search ===")
best_B = None
for lam in lambda_candidates():
    res = solve_milp_and_vrp(
        case_name=f"B_LambdaOnly_lam{lam}",
        lam=lam,
        min_cust=None,
        use_capacity=True,
        vrp_time_limit=5,
        do_plot=False
    )
    if res is None:
        print(f"  λ={lam:.2f} → infeasible")
        continue
    print(f"  λ={lam:.2f} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
    if (best_B is None) or (res["total_cost"] < best_B["total_cost"]):
        best_B = res
results_all["B_LambdaOnly"] = best_B

# C. 제약 2만 (MIN_CUST) → 여러 min_cust 중 최적 찾기
print("\n=== C_MinCustOnly — min_cust grid search ===")
best_C = None
for mc in min_cust_candidates():
    res = solve_milp_and_vrp(
        case_name=f"C_MinCustOnly_mc{mc}",
        lam=None,
        min_cust=mc,
        use_capacity=True,
        vrp_time_limit=5,
        do_plot=False
    )
    if res is None:
        print(f"  min_cust={mc} → infeasible")
        continue
    print(f"  min_cust={mc} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
    if (best_C is None) or (res["total_cost"] < best_C["total_cost"]):
        best_C = res
results_all["C_MinCustOnly"] = best_C

# D. 제약 1+2 동시 적용 → (λ, min_cust) 조합 전부 탐색
print("\n=== D_Both — (λ, min_cust) grid search ===")
best_D = None
for lam in lambda_candidates():
    for mc in min_cust_candidates():
        res = solve_milp_and_vrp(
            case_name=f"D_Both_lam{lam}_mc{mc}",
            lam=lam,
            min_cust=mc,
            use_capacity=True,
            vrp_time_limit=5,
            do_plot=False
        )
        if res is None:
            print(f"  λ={lam:.2f}, min_cust={mc} → infeasible")
            continue
        print(f"  λ={lam:.2f}, min_cust={mc} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
        if (best_D is None) or (res["total_cost"] < best_D["total_cost"]):
            best_D = res
results_all["D_Both"] = best_D

# ---------------------------------------------
# 7) 최종 비교 출력
# ---------------------------------------------
print("\n================ 최종 비교 ================")
for k, res in results_all.items():
    if res is None:
        print(k, "→ infeasible or failed")
    else:
        print(
            f"{k}: TOTAL={res['total_cost']:.2f}, opened={res['opened']}, "
            f"λ={res['lambda']}, min_cust={res['min_cust']}"
        )
print("==========================================")
# Out:
# ============================
# [A_NoConstraint] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [A_NoConstraint] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
# === B_LambdaOnly — λ grid search ===
#
# ============================
# [B_LambdaOnly_lam0.1] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.15] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.2] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.25] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | VRP 거리 = 127.49, routes = [[0, 7, 0], [0, 4, 2, 9, 3, 5, 10, 6, 8, 1, 0]]
#   DC 1 | VRP 거리 = 137.80, routes = [[0, 1, 0], [0, 5, 2, 4, 9, 8, 7, 6, 3, 11, 10, 0]]
#   DC 2 | VRP 거리 = 168.98, routes = [[0, 4, 5, 1, 10, 0], [0, 9, 12, 7, 2, 3, 6, 11, 8, 0]]
#   DC 3 | VRP 거리 = 127.57, routes = [[0, 4, 8, 9, 3, 5, 2, 0], [0, 12, 11, 1, 10, 6, 7, 0]]
#   DC 4 | VRP 거리 = 67.29, routes = [[0, 2, 3, 4, 1, 5, 0]]
#
# [B_LambdaOnly_lam0.25] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 629.126
#   총비용: 829.126
#   λ=0.25 → TOTAL=829.13, opened=[0, 1, 2, 3, 4]
#
# ============================
# [B_LambdaOnly_lam0.3] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 140.40, routes = [[0, 8, 11, 0], [0, 4, 2, 3, 6, 7, 10, 9, 5, 1, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 173.38, routes = [[0, 4, 5, 1, 14, 10, 0], [0, 8, 11, 6, 3, 2, 7, 12, 9, 13, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.3] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.085
#   총비용: 738.085
#   λ=0.30 → TOTAL=738.09, opened=[0, 1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.35] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 126.00, routes = [[0, 7, 1, 4, 8, 9, 6, 2, 5, 10, 3, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 174.28, routes = [[0, 5, 6, 2, 15, 11, 1, 0], [0, 9, 12, 7, 4, 3, 8, 13, 10, 14, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.35] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.5889999999999
#   총비용: 724.5889999999999
#   λ=0.35 → TOTAL=724.59, opened=[0, 1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.4] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 204.71, routes = [[0, 17, 18, 6, 13, 14, 15, 16, 4, 11, 5, 0], [0, 10, 1, 9, 8, 7, 2, 12, 3, 0]]
#   DC 2 | VRP 거리 = 213.54, routes = [[0, 16, 19, 15, 12, 6, 18, 2, 7, 13, 10, 0], [0, 11, 17, 9, 3, 4, 8, 14, 5, 1, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.4] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.826
#   총비용: 681.826
#   λ=0.40 → TOTAL=681.83, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.45] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 186.00, routes = [[0, 11, 2, 6, 7, 8, 1, 9, 0], [0, 3, 5, 10, 4, 15, 14, 13, 12, 17, 16, 0]]
#   DC 2 | VRP 거리 = 234.83, routes = [[0, 11, 12, 18, 9, 3, 4, 8, 15, 0], [0, 13, 16, 20, 17, 0], [0, 1, 14, 6, 19, 2, 7, 5, 10, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.45] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 564.4069999999999
#   총비용: 684.4069999999999
#   λ=0.45 → TOTAL=684.41, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.5] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.22, routes = [[0, 10, 2, 6, 7, 1, 8, 0], [0, 3, 9, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 260.22, routes = [[0, 10, 15, 5, 14, 1, 0], [0, 11, 20, 12, 19, 9, 3, 4, 8, 0], [0, 13, 7, 2, 21, 6, 16, 18, 22, 17, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.017
#   총비용: 687.017
#   λ=0.50 → TOTAL=687.02, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.55] MILP + VRP 풀이 시작
#   λ = 0.55, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.55] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.55 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.6] MILP + VRP 풀이 시작
#   λ = 0.6, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.6] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.60 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.65] MILP + VRP 풀이 시작
#   λ = 0.65, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.65] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.65 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.7] MILP + VRP 풀이 시작
#   λ = 0.7, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.7] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.70 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.75] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.75] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.75 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.8] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.8] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.80 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.85] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.85] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.85 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.9] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [B_LambdaOnly_lam0.9] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.90 → TOTAL=677.48, opened=[1, 2, 3]
#
# === C_MinCustOnly — min_cust grid search ===
#
# ============================
# [C_MinCustOnly_mc5] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [C_MinCustOnly_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   min_cust=5 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc10] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [C_MinCustOnly_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   min_cust=10 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc15] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 239.41, routes = [[0, 10, 11, 0], [0, 5, 15, 8, 4, 3, 9, 17, 12, 18, 0], [0, 20, 16, 13, 6, 19, 2, 7, 14, 1, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [C_MinCustOnly_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 572.129
#   총비용: 692.129
#   min_cust=15 → TOTAL=692.13, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc20] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 321.36, routes = [[0, 28, 10, 13, 22, 27, 25, 15, 23, 24, 29, 0], [0, 30, 19, 21, 1, 20, 0], [0, 14, 11, 4, 5, 9, 18, 12, 0], [0, 16, 7, 26, 3, 8, 6, 17, 2, 0]]
#   DC 3 | VRP 거리 = 196.73, routes = [[0, 20, 19, 1, 3, 18, 12, 17, 10, 13, 0], [0, 4, 16, 2, 11, 7, 8, 15, 14, 5, 9, 6, 0]]
#
# [C_MinCustOnly_mc20] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 518.091
#   총비용: 598.091
#   min_cust=20 → TOTAL=598.09, opened=[2, 3]
#
# ============================
# [C_MinCustOnly_mc25] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 4]
#   DC 2 | VRP 거리 = 276.44, routes = [[0, 11, 17, 10, 3, 4, 8, 5, 1, 0], [0, 24, 9, 12, 22, 14, 20, 21, 13, 0], [0, 19, 25, 18, 15, 6, 23, 2, 7, 16, 0]]
#   DC 4 | VRP 거리 = 239.76, routes = [[0, 13, 23, 18, 21, 4, 22, 14, 20, 11, 2, 24, 19, 0], [0, 1, 8, 12, 9, 17, 16, 6, 10, 7, 15, 25, 5, 0], [0, 3, 0]]
#
# [C_MinCustOnly_mc25] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 516.2059999999999
#   총비용: 596.2059999999999
#   min_cust=25 → TOTAL=596.21, opened=[2, 4]
#
# ============================
# [C_MinCustOnly_mc30] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1]
#   DC 1 | VRP 거리 = 585.69, routes = [[0, 48, 7, 43, 3, 8, 6, 25, 14, 46, 0], [0, 11, 16, 22, 28, 31, 26, 23, 24, 2, 27, 32, 0], [0, 37, 17, 41, 40, 19, 42, 44, 15, 45, 33, 39, 10, 0], [0, 1, 36, 35, 20, 29, 21, 50, 34, 30, 49, 38, 0], [0, 18, 9, 5, 4, 13, 47, 12, 0]]
#
# [C_MinCustOnly_mc30] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 585.693
#   총비용: 625.693
#   min_cust=30 → TOTAL=625.69, opened=[1]
#
# ============================
# [C_MinCustOnly_mc35] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1]
#   DC 1 | VRP 거리 = 585.69, routes = [[0, 48, 7, 43, 3, 8, 6, 25, 14, 46, 0], [0, 11, 16, 22, 28, 31, 26, 23, 24, 2, 27, 32, 0], [0, 37, 17, 41, 40, 19, 42, 44, 15, 45, 33, 39, 10, 0], [0, 1, 36, 35, 20, 29, 21, 50, 34, 30, 49, 38, 0], [0, 18, 9, 5, 4, 13, 47, 12, 0]]
#
# [C_MinCustOnly_mc35] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 585.693
#   총비용: 625.693
#   min_cust=35 → TOTAL=625.69, opened=[1]
#
# ============================
# [C_MinCustOnly_mc40] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1]
#   DC 1 | VRP 거리 = 585.69, routes = [[0, 48, 7, 43, 3, 8, 6, 25, 14, 46, 0], [0, 11, 16, 22, 28, 31, 26, 23, 24, 2, 27, 32, 0], [0, 37, 17, 41, 40, 19, 42, 44, 15, 45, 33, 39, 10, 0], [0, 1, 36, 35, 20, 29, 21, 50, 34, 30, 49, 38, 0], [0, 18, 9, 5, 4, 13, 47, 12, 0]]
#
# [C_MinCustOnly_mc40] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 585.693
#   총비용: 625.693
#   min_cust=40 → TOTAL=625.69, opened=[1]
#
# ============================
# [C_MinCustOnly_mc45] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1]
#   DC 1 | VRP 거리 = 585.69, routes = [[0, 48, 7, 43, 3, 8, 6, 25, 14, 46, 0], [0, 11, 16, 22, 28, 31, 26, 23, 24, 2, 27, 32, 0], [0, 37, 17, 41, 40, 19, 42, 44, 15, 45, 33, 39, 10, 0], [0, 1, 36, 35, 20, 29, 21, 50, 34, 30, 49, 38, 0], [0, 18, 9, 5, 4, 13, 47, 12, 0]]
#
# [C_MinCustOnly_mc45] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 585.693
#   총비용: 625.693
#   min_cust=45 → TOTAL=625.69, opened=[1]
#
# ============================
# [C_MinCustOnly_mc50] MILP + VRP 풀이 시작
#   λ = None, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1]
#   DC 1 | VRP 거리 = 585.69, routes = [[0, 48, 7, 43, 3, 8, 6, 25, 14, 46, 0], [0, 11, 16, 22, 28, 31, 26, 23, 24, 2, 27, 32, 0], [0, 37, 17, 41, 40, 19, 42, 44, 15, 45, 33, 39, 10, 0], [0, 1, 36, 35, 20, 29, 21, 50, 34, 30, 49, 38, 0], [0, 18, 9, 5, 4, 13, 47, 12, 0]]
#
# [C_MinCustOnly_mc50] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 585.693
#   총비용: 625.693
#   min_cust=50 → TOTAL=625.69, opened=[1]
#
# === D_Both — (λ, min_cust) grid search ===
#
# ============================
# [D_Both_lam0.1_mc5] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.1_mc10] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.1_mc15] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.1_mc20] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.1_mc25] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.1_mc30] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.1_mc35] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.1_mc40] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.1_mc45] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.1_mc50] MILP + VRP 풀이 시작
#   λ = 0.1, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.15_mc5] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.15_mc10] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.15_mc15] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.15_mc20] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.15_mc25] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.15_mc30] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.15_mc35] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.15_mc40] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.15_mc45] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.15_mc50] MILP + VRP 풀이 시작
#   λ = 0.15, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.2_mc5] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.2_mc10] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.2_mc15] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.2_mc20] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.2_mc25] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.2_mc30] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.2_mc35] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.2_mc40] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.2_mc45] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.2_mc50] MILP + VRP 풀이 시작
#   λ = 0.2, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.25_mc5] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | VRP 거리 = 127.49, routes = [[0, 7, 0], [0, 4, 2, 9, 3, 5, 10, 6, 8, 1, 0]]
#   DC 1 | VRP 거리 = 137.80, routes = [[0, 1, 0], [0, 5, 2, 4, 9, 8, 7, 6, 3, 11, 10, 0]]
#   DC 2 | VRP 거리 = 168.98, routes = [[0, 4, 5, 1, 10, 0], [0, 9, 12, 7, 2, 3, 6, 11, 8, 0]]
#   DC 3 | VRP 거리 = 127.57, routes = [[0, 4, 8, 9, 3, 5, 2, 0], [0, 12, 11, 1, 10, 6, 7, 0]]
#   DC 4 | VRP 거리 = 67.29, routes = [[0, 2, 3, 4, 1, 5, 0]]
#
# [D_Both_lam0.25_mc5] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 629.126
#   총비용: 829.126
#   λ=0.25, min_cust=5 → TOTAL=829.13, opened=[0, 1, 2, 3, 4]
#
# ============================
# [D_Both_lam0.25_mc10] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | VRP 거리 = 112.90, routes = [[0, 8, 0], [0, 4, 6, 3, 1, 9, 2, 5, 7, 10, 0]]
#   DC 1 | VRP 거리 = 103.64, routes = [[0, 1, 5, 2, 8, 7, 6, 4, 3, 10, 9, 0]]
#   DC 2 | VRP 거리 = 143.21, routes = [[0, 1, 4, 0], [0, 7, 8, 5, 3, 2, 6, 9, 10, 0]]
#   DC 3 | VRP 거리 = 95.90, routes = [[0, 2, 4, 3, 7, 5, 8, 6, 1, 9, 10, 0]]
#   DC 4 | VRP 거리 = 105.38, routes = [[0, 7, 1, 4, 6, 5, 9, 8, 3, 10, 2, 0]]
#
# [D_Both_lam0.25_mc10] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 561.038
#   총비용: 761.038
#   λ=0.25, min_cust=10 → TOTAL=761.04, opened=[0, 1, 2, 3, 4]
#
# ============================
# [D_Both_lam0.25_mc15] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.25_mc20] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.25_mc25] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.25_mc30] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.25_mc35] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.25_mc40] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.25_mc45] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.25_mc50] MILP + VRP 풀이 시작
#   λ = 0.25, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.3_mc5] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 140.40, routes = [[0, 8, 11, 0], [0, 4, 2, 3, 6, 7, 10, 9, 5, 1, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 173.38, routes = [[0, 4, 5, 1, 14, 10, 0], [0, 8, 11, 6, 3, 2, 7, 12, 9, 13, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.3_mc5] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.085
#   총비용: 738.085
#   λ=0.30, min_cust=5 → TOTAL=738.09, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.3_mc10] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 140.40, routes = [[0, 8, 11, 0], [0, 4, 2, 3, 6, 7, 10, 9, 5, 1, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 173.38, routes = [[0, 4, 5, 1, 14, 10, 0], [0, 8, 11, 6, 3, 2, 7, 12, 9, 13, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.3_mc10] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.085
#   총비용: 738.085
#   λ=0.30, min_cust=10 → TOTAL=738.09, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.3_mc15] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.3_mc20] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.3_mc25] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.3_mc30] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.3_mc35] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.3_mc40] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.3_mc45] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.3_mc50] MILP + VRP 풀이 시작
#   λ = 0.3, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.35_mc5] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 126.00, routes = [[0, 7, 1, 4, 8, 9, 6, 2, 5, 10, 3, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 174.28, routes = [[0, 5, 6, 2, 15, 11, 1, 0], [0, 9, 12, 7, 4, 3, 8, 13, 10, 14, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.35_mc5] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.5889999999999
#   총비용: 724.5889999999999
#   λ=0.35, min_cust=5 → TOTAL=724.59, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc10] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | VRP 거리 = 126.00, routes = [[0, 7, 1, 4, 8, 9, 6, 2, 5, 10, 3, 0]]
#   DC 1 | VRP 거리 = 120.73, routes = [[0, 5, 0], [0, 11, 2, 12, 4, 8, 9, 10, 3, 6, 7, 1, 0]]
#   DC 2 | VRP 거리 = 174.28, routes = [[0, 5, 6, 2, 15, 11, 1, 0], [0, 9, 12, 7, 4, 3, 8, 13, 10, 14, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.35_mc10] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.5889999999999
#   총비용: 724.5889999999999
#   λ=0.35, min_cust=10 → TOTAL=724.59, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc15] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [0, 2, 3]
#   DC 0 | VRP 거리 = 185.72, routes = [[0, 11, 1, 6, 9, 10, 7, 2, 3, 16, 8, 0], [0, 5, 15, 13, 12, 4, 14, 0]]
#   DC 2 | VRP 거리 = 191.08, routes = [[0, 8, 1, 12, 5, 2, 17, 11, 0], [0, 13, 6, 4, 3, 7, 15, 14, 10, 16, 9, 0]]
#   DC 3 | VRP 거리 = 178.21, routes = [[0, 17, 6, 11, 12, 5, 7, 4, 0], [0, 2, 13, 16, 1, 3, 15, 9, 14, 8, 10, 0]]
#
# [D_Both_lam0.35_mc15] 결과 요약
#   개설된 DC: [0, 2, 3]
#   개설비용: 120
#   VRP 비용: 555.015
#   총비용: 675.015
#   λ=0.35, min_cust=15 → TOTAL=675.01, opened=[0, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc20] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.35_mc25] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.35_mc30] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.35_mc35] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.35_mc40] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.35_mc45] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.35_mc50] MILP + VRP 풀이 시작
#   λ = 0.35, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.4_mc5] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 204.71, routes = [[0, 17, 18, 6, 13, 14, 15, 16, 4, 11, 5, 0], [0, 10, 1, 9, 8, 7, 2, 12, 3, 0]]
#   DC 2 | VRP 거리 = 213.54, routes = [[0, 16, 19, 15, 12, 6, 18, 2, 7, 13, 10, 0], [0, 11, 17, 9, 3, 4, 8, 14, 5, 1, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.4_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.826
#   총비용: 681.826
#   λ=0.40, min_cust=5 → TOTAL=681.83, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc10] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 204.71, routes = [[0, 17, 18, 6, 13, 14, 15, 16, 4, 11, 5, 0], [0, 10, 1, 9, 8, 7, 2, 12, 3, 0]]
#   DC 2 | VRP 거리 = 213.54, routes = [[0, 16, 19, 15, 12, 6, 18, 2, 7, 13, 10, 0], [0, 11, 17, 9, 3, 4, 8, 14, 5, 1, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.4_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.826
#   총비용: 681.826
#   λ=0.40, min_cust=10 → TOTAL=681.83, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc15] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 193.91, routes = [[0, 2, 7, 8, 1, 9, 15, 3, 0], [0, 16, 6, 11, 12, 13, 14, 4, 10, 5, 0]]
#   DC 2 | VRP 거리 = 213.54, routes = [[0, 16, 19, 15, 12, 6, 18, 2, 7, 13, 10, 0], [0, 11, 17, 9, 3, 4, 8, 14, 5, 1, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.4_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 576.478
#   총비용: 696.478
#   λ=0.40, min_cust=15 → TOTAL=696.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc20] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.4_mc25] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.4_mc30] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.4_mc35] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.4_mc40] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.4_mc45] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.4_mc50] MILP + VRP 풀이 시작
#   λ = 0.4, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.45_mc5] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 186.00, routes = [[0, 11, 2, 6, 7, 8, 1, 9, 0], [0, 3, 5, 10, 4, 15, 14, 13, 12, 17, 16, 0]]
#   DC 2 | VRP 거리 = 234.83, routes = [[0, 11, 12, 18, 9, 3, 4, 8, 15, 0], [0, 13, 16, 20, 17, 0], [0, 1, 14, 6, 19, 2, 7, 5, 10, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.45_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 564.4069999999999
#   총비용: 684.4069999999999
#   λ=0.45, min_cust=5 → TOTAL=684.41, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc10] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 186.00, routes = [[0, 11, 2, 6, 7, 8, 1, 9, 0], [0, 3, 5, 10, 4, 15, 14, 13, 12, 17, 16, 0]]
#   DC 2 | VRP 거리 = 234.83, routes = [[0, 11, 12, 18, 9, 3, 4, 8, 15, 0], [0, 13, 16, 20, 17, 0], [0, 1, 14, 6, 19, 2, 7, 5, 10, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.45_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 564.4069999999999
#   총비용: 684.4069999999999
#   λ=0.45, min_cust=10 → TOTAL=684.41, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc15] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 172.36, routes = [[0, 2, 6, 7, 1, 8, 0], [0, 3, 5, 9, 4, 13, 12, 11, 10, 15, 14, 0]]
#   DC 2 | VRP 거리 = 234.83, routes = [[0, 11, 12, 18, 9, 3, 4, 8, 15, 0], [0, 13, 16, 20, 17, 0], [0, 1, 14, 6, 19, 2, 7, 5, 10, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.45_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 576.22
#   총비용: 696.22
#   λ=0.45, min_cust=15 → TOTAL=696.22, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc20] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.45_mc25] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.45_mc30] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.45_mc35] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.45_mc40] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.45_mc45] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.45_mc50] MILP + VRP 풀이 시작
#   λ = 0.45, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.5_mc5] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.22, routes = [[0, 10, 2, 6, 7, 1, 8, 0], [0, 3, 9, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 260.22, routes = [[0, 10, 15, 5, 14, 1, 0], [0, 11, 20, 12, 19, 9, 3, 4, 8, 0], [0, 13, 7, 2, 21, 6, 16, 18, 22, 17, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.5_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.017
#   총비용: 687.017
#   λ=0.50, min_cust=5 → TOTAL=687.02, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc10] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.22, routes = [[0, 10, 2, 6, 7, 1, 8, 0], [0, 3, 9, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 260.22, routes = [[0, 10, 15, 5, 14, 1, 0], [0, 11, 20, 12, 19, 9, 3, 4, 8, 0], [0, 13, 7, 2, 21, 6, 16, 18, 22, 17, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.5_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.017
#   총비용: 687.017
#   λ=0.50, min_cust=10 → TOTAL=687.02, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc15] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 236.79, routes = [[0, 10, 1, 7, 2, 19, 6, 13, 16, 20, 0], [0, 18, 12, 17, 9, 3, 4, 8, 15, 5, 14, 0], [0, 11, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.5_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.509
#   총비용: 689.509
#   λ=0.50, min_cust=15 → TOTAL=689.51, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc20] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.5_mc25] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.5_mc30] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.5_mc35] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.5_mc40] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.5_mc45] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.5_mc50] MILP + VRP 풀이 시작
#   λ = 0.5, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.55_mc5] MILP + VRP 풀이 시작
#   λ = 0.55, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.55_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.55, min_cust=5 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc10] MILP + VRP 풀이 시작
#   λ = 0.55, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.55_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.55, min_cust=10 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc15] MILP + VRP 풀이 시작
#   λ = 0.55, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 239.41, routes = [[0, 10, 11, 0], [0, 5, 15, 8, 4, 3, 9, 17, 12, 18, 0], [0, 20, 16, 13, 6, 19, 2, 7, 14, 1, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.55_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 572.129
#   총비용: 692.129
#   λ=0.55, min_cust=15 → TOTAL=692.13, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc20] MILP + VRP 풀이 시작
#   λ = 0.55, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 282.17, routes = [[0, 2, 16, 6, 8, 3, 23, 7, 15, 0], [0, 12, 14, 21, 22, 10, 4, 5, 9, 17, 11, 0], [0, 13, 25, 24, 19, 1, 20, 18, 26, 0]]
# ...
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 321.36, routes = [[0, 28, 10, 13, 22, 27, 25, 15, 23, 24, 29, 0], [0, 30, 19, 21, 1, 20, 0], [0, 14, 11, 4, 5, 9, 18, 12, 0], [0, 16, 7, 26, 3, 8, 6, 17, 2, 0]]
#   DC 3 | VRP 거리 = 196.73, routes = [[0, 20, 19, 1, 3, 18, 12, 17, 10, 13, 0], [0, 4, 16, 2, 11, 7, 8, 15, 14, 5, 9, 6, 0]]
#
# [D_Both_lam0.75_mc20] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 518.091
#   총비용: 598.091
#   λ=0.75, min_cust=20 → TOTAL=598.09, opened=[2, 3]
#
# ============================
# [D_Both_lam0.75_mc25] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 4]
#   DC 2 | VRP 거리 = 276.44, routes = [[0, 11, 17, 10, 3, 4, 8, 5, 1, 0], [0, 24, 9, 12, 22, 14, 20, 21, 13, 0], [0, 19, 25, 18, 15, 6, 23, 2, 7, 16, 0]]
#   DC 4 | VRP 거리 = 239.76, routes = [[0, 13, 23, 18, 21, 4, 22, 14, 20, 11, 2, 24, 19, 0], [0, 1, 8, 12, 9, 17, 16, 6, 10, 7, 15, 25, 5, 0], [0, 3, 0]]
#
# [D_Both_lam0.75_mc25] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 516.2059999999999
#   총비용: 596.2059999999999
#   λ=0.75, min_cust=25 → TOTAL=596.21, opened=[2, 4]
#
# ============================
# [D_Both_lam0.75_mc30] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.75_mc35] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.75_mc40] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.75_mc45] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.75_mc50] MILP + VRP 풀이 시작
#   λ = 0.75, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.8_mc5] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.8_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.80, min_cust=5 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc10] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.8_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.80, min_cust=10 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc15] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 236.79, routes = [[0, 10, 1, 7, 2, 19, 6, 13, 16, 20, 0], [0, 18, 12, 17, 9, 3, 4, 8, 15, 5, 14, 0], [0, 11, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.8_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.509
#   총비용: 689.509
#   λ=0.80, min_cust=15 → TOTAL=689.51, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc20] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 321.36, routes = [[0, 28, 10, 13, 22, 27, 25, 15, 23, 24, 29, 0], [0, 30, 19, 21, 1, 20, 0], [0, 14, 11, 4, 5, 9, 18, 12, 0], [0, 16, 7, 26, 3, 8, 6, 17, 2, 0]]
#   DC 3 | VRP 거리 = 196.73, routes = [[0, 20, 19, 1, 3, 18, 12, 17, 10, 13, 0], [0, 4, 16, 2, 11, 7, 8, 15, 14, 5, 9, 6, 0]]
#
# [D_Both_lam0.8_mc20] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 518.091
#   총비용: 598.091
#   λ=0.80, min_cust=20 → TOTAL=598.09, opened=[2, 3]
#
# ============================
# [D_Both_lam0.8_mc25] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 4]
#   DC 2 | VRP 거리 = 276.44, routes = [[0, 11, 17, 10, 3, 4, 8, 5, 1, 0], [0, 24, 9, 12, 22, 14, 20, 21, 13, 0], [0, 19, 25, 18, 15, 6, 23, 2, 7, 16, 0]]
#   DC 4 | VRP 거리 = 239.76, routes = [[0, 13, 23, 18, 21, 4, 22, 14, 20, 11, 2, 24, 19, 0], [0, 1, 8, 12, 9, 17, 16, 6, 10, 7, 15, 25, 5, 0], [0, 3, 0]]
#
# [D_Both_lam0.8_mc25] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 516.2059999999999
#   총비용: 596.2059999999999
#   λ=0.80, min_cust=25 → TOTAL=596.21, opened=[2, 4]
#
# ============================
# [D_Both_lam0.8_mc30] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.8_mc35] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.8_mc40] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.8_mc45] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.8_mc50] MILP + VRP 풀이 시작
#   λ = 0.8, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.85_mc5] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.85_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.85, min_cust=5 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc10] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.85_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.85, min_cust=10 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc15] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 236.79, routes = [[0, 10, 1, 7, 2, 19, 6, 13, 16, 20, 0], [0, 18, 12, 17, 9, 3, 4, 8, 15, 5, 14, 0], [0, 11, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.85_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.509
#   총비용: 689.509
#   λ=0.85, min_cust=15 → TOTAL=689.51, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc20] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 321.36, routes = [[0, 28, 10, 13, 22, 27, 25, 15, 23, 24, 29, 0], [0, 30, 19, 21, 1, 20, 0], [0, 14, 11, 4, 5, 9, 18, 12, 0], [0, 16, 7, 26, 3, 8, 6, 17, 2, 0]]
#   DC 3 | VRP 거리 = 196.73, routes = [[0, 20, 19, 1, 3, 18, 12, 17, 10, 13, 0], [0, 4, 16, 2, 11, 7, 8, 15, 14, 5, 9, 6, 0]]
#
# [D_Both_lam0.85_mc20] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 518.091
#   총비용: 598.091
#   λ=0.85, min_cust=20 → TOTAL=598.09, opened=[2, 3]
#
# ============================
# [D_Both_lam0.85_mc25] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 4]
#   DC 2 | VRP 거리 = 276.44, routes = [[0, 11, 17, 10, 3, 4, 8, 5, 1, 0], [0, 24, 9, 12, 22, 14, 20, 21, 13, 0], [0, 19, 25, 18, 15, 6, 23, 2, 7, 16, 0]]
#   DC 4 | VRP 거리 = 239.76, routes = [[0, 13, 23, 18, 21, 4, 22, 14, 20, 11, 2, 24, 19, 0], [0, 1, 8, 12, 9, 17, 16, 6, 10, 7, 15, 25, 5, 0], [0, 3, 0]]
#
# [D_Both_lam0.85_mc25] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 516.2059999999999
#   총비용: 596.2059999999999
#   λ=0.85, min_cust=25 → TOTAL=596.21, opened=[2, 4]
#
# ============================
# [D_Both_lam0.85_mc30] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.85_mc35] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.85_mc40] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.85_mc45] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.85_mc50] MILP + VRP 풀이 시작
#   λ = 0.85, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.9_mc5] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.9_mc5] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.90, min_cust=5 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc10] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 134.39, routes = [[0, 13, 3, 5, 9, 11, 12, 4, 10, 2, 6, 7, 1, 8, 0]]
#   DC 2 | VRP 거리 = 279.52, routes = [[0, 11, 15, 5, 14, 1, 10, 0], [0, 13, 7, 2, 22, 6, 16, 18, 24, 17, 0], [0, 23, 21, 12, 19, 20, 9, 3, 4, 8, 0]]
#   DC 3 | VRP 거리 = 143.58, routes = [[0, 4, 9, 10, 3, 5, 2, 0], [0, 8, 6, 11, 7, 1, 12, 13, 0]]
#
# [D_Both_lam0.9_mc10] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.482
#   총비용: 677.482
#   λ=0.90, min_cust=10 → TOTAL=677.48, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc15] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | VRP 거리 = 163.69, routes = [[0, 2, 9, 1, 6, 8, 7, 0], [0, 3, 10, 4, 13, 12, 11, 5, 15, 14, 0]]
#   DC 2 | VRP 거리 = 239.41, routes = [[0, 10, 11, 0], [0, 5, 15, 8, 4, 3, 9, 17, 12, 18, 0], [0, 20, 16, 13, 6, 19, 2, 7, 14, 1, 0]]
#   DC 3 | VRP 거리 = 169.03, routes = [[0, 15, 9, 7, 13, 8, 1, 14, 12, 0], [0, 2, 5, 11, 10, 3, 6, 4, 0]]
#
# [D_Both_lam0.9_mc15] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 572.129
#   총비용: 692.129
#   λ=0.90, min_cust=15 → TOTAL=692.13, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc20] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 3]
#   DC 2 | VRP 거리 = 321.36, routes = [[0, 28, 10, 13, 22, 27, 25, 15, 23, 24, 29, 0], [0, 30, 19, 21, 1, 20, 0], [0, 14, 11, 4, 5, 9, 18, 12, 0], [0, 16, 7, 26, 3, 8, 6, 17, 2, 0]]
#   DC 3 | VRP 거리 = 196.73, routes = [[0, 20, 19, 1, 3, 18, 12, 17, 10, 13, 0], [0, 4, 16, 2, 11, 7, 8, 15, 14, 5, 9, 6, 0]]
#
# [D_Both_lam0.9_mc20] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 518.091
#   총비용: 598.091
#   λ=0.90, min_cust=20 → TOTAL=598.09, opened=[2, 3]
#
# ============================
# [D_Both_lam0.9_mc25] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: Optimal
# 개설된 DC: [2, 4]
#   DC 2 | VRP 거리 = 276.44, routes = [[0, 11, 17, 10, 3, 4, 8, 5, 1, 0], [0, 24, 9, 12, 22, 14, 20, 21, 13, 0], [0, 19, 25, 18, 15, 6, 23, 2, 7, 16, 0]]
#   DC 4 | VRP 거리 = 239.76, routes = [[0, 13, 23, 18, 21, 4, 22, 14, 20, 11, 2, 24, 19, 0], [0, 1, 8, 12, 9, 17, 16, 6, 10, 7, 15, 25, 5, 0], [0, 3, 0]]
#
# [D_Both_lam0.9_mc25] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 516.2059999999999
#   총비용: 596.2059999999999
#   λ=0.90, min_cust=25 → TOTAL=596.21, opened=[2, 4]
#
# ============================
# [D_Both_lam0.9_mc30] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.9_mc35] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.9_mc40] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.9_mc45] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.9_mc50] MILP + VRP 풀이 시작
#   λ = 0.9, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: Infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=50 → infeasible
#
# ================ 최종 비교 ================
# A_None: TOTAL=677.48, opened=[1, 2, 3], λ=None, min_cust=None
# B_LambdaOnly: TOTAL=677.48, opened=[1, 2, 3], λ=0.55, min_cust=None
# C_MinCustOnly: TOTAL=596.21, opened=[2, 4], λ=None, min_cust=25
# D_Both: TOTAL=596.21, opened=[2, 4], λ=0.6, min_cust=25
# ==========================================

# %%
import matplotlib.pyplot as plt

# ============================================================
# 1) 기본 시각화: DC + 경로만 (Demand 라벨 X)
# ============================================================
def plot_case_all_dc(result, title=""):
    """
    result: results_all[...] 중 하나
      - result["opened"]        : 열린 DC 리스트
      - result["routes_detail"] : 각 DC별 {routes, locs, customers}
    """
    if result is None:
        print(f"[{title}] 결과가 없습니다 (infeasible or failed).")
        return

    routes_detail = result["routes_detail"]
    opened        = result["opened"]

    plt.figure(figsize=(7, 7))

    # 배경에 전체 고객 위치 (연한 회색)
    plt.scatter(
        customer["X"], customer["Y"],
        c="lightgray", s=15, alpha=0.5, label="All Customers"
    )

    for dc_id in opened:
        detail = routes_detail[dc_id]
        routes = detail["routes"]
        locs   = detail["locs"]   # 0: depot(DC), 1~: 이 DC가 담당하는 고객들

        # DC 위치
        x_dc, y_dc = locs[0]
        plt.scatter(
            x_dc, y_dc,
            c="red", marker="X", s=180,
            label=f"DC {dc_id}"
        )

        # 경로(트럭 route들)
        for route in routes:
            xs, ys = [], []
            for node in route:
                x, y = locs[node]
                xs.append(x); ys.append(y)

                # 고객 노드만 파란 점
                if node != 0:
                    plt.scatter(x, y, c="blue", s=30)
            # 경로 선
            plt.plot(xs, ys, alpha=0.8)

    plt.title(title)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)

    # 중복 레이블 제거
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), fontsize=8)

    plt.show()


# ============================================================
# 2) Demand(수요) 라벨까지 같이 표시하는 버전
# ============================================================
def plot_case_all_dc_with_demand(result, title=""):
    if result is None:
        print(f"[{title}] 결과가 없습니다 (infeasible or failed).")
        return

    routes_detail = result["routes_detail"]
    opened        = result["opened"]

    plt.figure(figsize=(7, 7))

    # 전체 고객 위치 (옅게만)
    plt.scatter(
        customer["X"], customer["Y"],
        c="lightgray", s=15, alpha=0.5
    )

    # 이미 라벨 찍은 고객은 다시 안 찍도록 관리
    already_labeled = set()

    for dc_id in opened:
        detail = routes_detail[dc_id]
        routes = detail["routes"]
        locs   = detail["locs"]

        # DC
        x_dc, y_dc = locs[0]
        plt.scatter(
            x_dc, y_dc,
            c="red", marker="X", s=180,
            label=f"DC {dc_id}"
        )

        # 경로 + Demand 라벨
        for route in routes:
            xs, ys = [], []
            for node in route:
                x, y = locs[node]
                xs.append(x); ys.append(y)

                if node != 0:
                    # 고객 점
                    plt.scatter(x, y, c="blue", s=35)

                    # global customer index (Customer.csv의 index)
                    global_index = detail["customers"][node-1]  # node=1 → customers[0]

                    # 아직 라벨 안 찍은 고객만
                    if global_index not in already_labeled:
                        d = int(customer.loc[global_index, "DEMAND"])

                        # 살짝 위치를 옆으로/위아래로 밀어서 겹침 줄이기
                        dx = 0.8 if (global_index % 2 == 0) else -1.0
                        dy = 0.8 if (global_index % 3 == 0) else -0.8

                        plt.text(
                            x + dx, y + dy, f"{d}",
                            fontsize=7, color="black",
                            ha="center", va="center",
                            bbox=dict(
                                facecolor="white",
                                edgecolor="none",
                                alpha=0.6
                            )
                        )
                        already_labeled.add(global_index)

            plt.plot(xs, ys, alpha=0.8)

    plt.title(title)
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.grid(True)

    # 중복 레이블 제거
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), fontsize=8)

    plt.show()


# ============================================================
# 3) Case별로 2장씩 시각화 호출
#    (기본 버전 + Demand 라벨 버전)
# ============================================================

# ---- Case 1: 제약 없음 ----
plot_case_all_dc(
    results_all["A_None"],
    title="Case 1 (A_None) — No Constraints"
)

plot_case_all_dc_with_demand(
    results_all["A_None"],
    title="Case 1 (A_None) — Demand"
)

# ---- Case 2: λ만 적용 ----
plot_case_all_dc(
    results_all["B_LambdaOnly"],
    title=f"Case 2 — λ Only (λ={results_all['B_LambdaOnly']['lambda']})"
)

plot_case_all_dc_with_demand(
    results_all["B_LambdaOnly"],
    title=f"Case 2 — Demand (λ={results_all['B_LambdaOnly']['lambda']})"
)

# ---- Case 3: MinCust만 적용 ----
plot_case_all_dc(
    results_all["C_MinCustOnly"],
    title=f"Case 3 — MinCust Only (min_cust={results_all['C_MinCustOnly']['min_cust']})"
)

plot_case_all_dc_with_demand(
    results_all["C_MinCustOnly"],
    title=f"Case 3 — Demand (min_cust={results_all['C_MinCustOnly']['min_cust']})"
)

# ---- Case 4: λ + MinCust 동시 적용 ----
plot_case_all_dc(
    results_all["D_Both"],
    title=f"Case 4 — λ + MinCust (λ={results_all['D_Both']['lambda']}, min_cust={results_all['D_Both']['min_cust']})"
)

plot_case_all_dc_with_demand(
    results_all["D_Both"],
    title=f"Case 4 — Demand (λ={results_all['D_Both']['lambda']}, min_cust={results_all['D_Both']['min_cust']})"
)
